# %% [markdown]
# # 2D simulation with SPECFEM2D
# By Andrea R. using utility functions written by Ridvan Orsvuran

# %%
import os
import numpy as np
from scipy.integrate import simps
import matplotlib.pyplot as plt
import obspy
import re
import IPython.display as dp
from PIL import Image

# %%
# Some utility functions (written by Ridvan Orsvuran)
def read_trace(filename):
    """Reads an ASCII file and returns a obspy Traces"""
    data = np.loadtxt(filename)
    # first column is time, second column is the data
    times = data[:, 0]
    disp = data[:, 1]
    # get station name from the filename
    net, sta, comp, *_ = filename.split("/")[-1].split(".")
    delta = times[1] - times[0]
    headers = {"station": sta, "network": net, "channel": comp, "delta": delta, "b": times[0]}
    return obspy.Trace(disp, headers)

def save_trace(tr, filename):
    """Writes out the traces as an ASCII file. Uses b value as the beginning."""
    data = np.zeros((len(tr.data), 2))
    data[:, 0] = tr.times()+tr.stats.b
    data[:, 1] = tr.data
    np.savetxt(filename, data)
       
def specfem_write_parameters(filename, parameters, output_file=None):
    """Write parameters to a specfem config file"""

    with open(filename) as f:
        pars = f.read()

    for varname, value in parameters.items():
        pat = re.compile(
            r"(^{varname}\s*=\s*)([^#$\s]+)".format(varname=varname),
            re.MULTILINE)
        pars = pat.sub(r"\g<1>{value}".format(value=value), pars)

    if output_file is None:
        output_file = filename

    with open(output_file, "w") as f:
        f.write(pars)     
        
def specfem2D_prep_save_forward(filename=None):
    if filename is None:
        filename = "./DATA/Par_file"
    params = {
        "SIMULATION_TYPE": 1,
        "SAVE_FORWARD": ".true."
    }
    specfem_write_parameters(filename, params)
    
def specfem2D_prep_adjoint(filename=None):
    if filename is None:
        filename = "./DATA/Par_file"
    params = {
        "SIMULATION_TYPE": 3,
        "SAVE_FORWARD": ".false."
    }
    specfem_write_parameters(filename, params)
      
def grid(x, y, z, resX=100, resY=100):
    """
    Converts 3 column data to matplotlib grid
    """
    # Can be found in ./utils/Visualization/plot_kernel.py
    from scipy.interpolate import griddata

    xi = np.linspace(min(x), max(x), resX)
    yi = np.linspace(min(y), max(y), resY)

    # mlab version
    #Z = griddata(x, y, z, xi, yi, interp='linear')
    # scipy version
    Z = griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')

    X, Y = np.meshgrid(xi, yi)
    return X, Y, Z

# %% [markdown]
# ### Domain:
# 2D:
# x-dir = 4000 m
# z-dir = 4000 m
#
# ### Source location
# original x:    1000 m
# original z:    2000 m
#
# ### Output station location:
# Station #1   AAS0001
# original x:    3000 m
# original z:    2000 m
#
# ### Boundary conditions
# Type: STACEY_ABSORBING_CONDITIONS
# absorbbottom                    = true
# absorbright                     = true
# absorbtop                       = true
# absorbleft                      = true
#
# ### Velocity model:
#
# Model: P (or PI) velocity min,max =    3000 m/s
# Model: S velocity min,max         =    1800 m/s
# Model: density min,max            =    2700 kg/m3

# %% [markdown]
# ### To reproduce this example copy the files in DATA to the specfem2d directory: specfem2d/DATA

# %% [markdown]
# ### Set Specfem2D directory path

# %%
specfem2d_path = "."

# %% [markdown]
# ### 1. Run the mesher

# %%
os.chdir(specfem2d_path)
# !$specfem2d_path/bin/xmeshfem2D
# Out:
#  **********************************************
#  *** Specfem 2-D Mesher - MPI version       ***
#  **********************************************
#
#  Running Git version of the code corresponding to fd7926e7eae5f9c0f614cf7d06e56c768ca3a9a4
#  dating 2022-12-13 20:03:51 +0100
#
#  Reading the parameter file...
#
#  Error: unknown model choosen default
#  Error bad model value for parameter MODEL
#  Error detected, aborting MPI... proc            0
# --------------------------------------------------------------------------
# MPI_ABORT was invoked on rank 0 in communicator MPI_COMM_WORLD
# with errorcode 30.
#
# NOTE: invoking MPI_ABORT causes Open MPI to kill all MPI processes.
# You may or may not see output from other processes, depending on
# exactly when Open MPI kills them.
# --------------------------------------------------------------------------

# %% [markdown]
# ### 2. Run the solver

# %%
# !$specfem2d_path/bin/xspecfem2D
# Out:
#  **********************************************
#  **** Specfem 2-D Solver - serial version  ****
#  **********************************************
#
#  Running Git version of the code corresponding to
#  dating From
#
#
#  NDIM =            2
#
#  NGLLX =            5
#  NGLLZ =            5
#
#  using single precision for the calculations
#
#  smallest and largest possible floating-point numbers are:    1.17549435E-38   3.40282347E+38
#
#  Reading the parameter file...
#
#  Title of the simulation: Test of SPECFEM2D with curved interfaces
#
#
#    using existing STATIONS file: ./DATA/STATIONS
#    file name is ./DATA/STATIONS
#    found            4  receivers
#
#  Parameter file successfully read
#
#  Reading in SOURCE file...
#
#  Source           1
#    Position xs, zs =    1000.0000000000000        2000.0000000000000
#
#    Source type (1=force, 2=moment tensor):            1
#    Force source:
#    Angle of the source (deg) =    0.0000000000000000
#
#    Time function type (1=Ricker, 2=First derivative, 3=Gaussian, 4=Dirac, 5=Heaviside, 6,7=ocean type, 8=Read from file, 9=burst, 10=Sinusoidal, 11=Ormsby):           1
#    Ricker wavelet (second-derivative):
#    Frequency, delay =    10.000000000000000        0.0000000000000000
#    Multiplying factor  =    10000000000.000000
#
#  all sources are okay
#
#
#
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#  Program SPECFEM2D:
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#  Test of SPECFEM2D with curved interfaces
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#  D a t e : 07 - 02 - 2023                                 T i m e  : 17:54:00
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#
#
#  C o n t r o l
#  =============
#
#      Number of spectral element control nodes. . .(npgeo) =   20449
#      Number of space dimensions. . . . . . . . . . (NDIM) =       2
#
#
#  C o n t r o l
#  =============
#
#      Display frequency . . . (NTSTEP_BETWEEN_OUTPUT_INFO) =    100
#      Color display . . . . . . . . . . . . . . . (colors) =      1
#       == 0     black and white display
#       == 1     color display
#      Numbered mesh . . . . . . . . . . . . . . .(numbers) =      0
#       == 0     do not number the mesh
#       == 1     number the mesh
#
#
#  C o n t r o l
#  =============
#
#      Seismograms recording type . . . . . . .(seismotype) = 1
#      Angle for first line of receivers. . . . .(anglerec) =   0.00
#
#
#  C o n t r o l
#  =============
#
#      Read external initial field. . . . . .(initialfield) =      F
#      Add Bielak conditions (add_Bielak_conditions_bottom) =      F
#      Add Bielak conditions .(add_Bielak_conditions_right) =      F
#      Add Bielak conditions . .(add_Bielak_conditions_top) =      F
#      Add Bielak conditions. .(add_Bielak_conditions_left) =      F
#      Attenuation in solid . . .(ATTENUATION_VISCOELASTIC) =      F
#      Attenuation in fluid . . (ATTENUATION_VISCOACOUSTIC) =      F
#      Save grid in ASCII file or not . (output_grid_ASCII) =      F
#      Save a file with total energy or not.(OUTPUT_ENERGY) =      F
#
#
#  C o n t r o l
#  =============
#
#      Vector display type . . . . . . . . .(imagetype_postscript) =      1
#      Percentage of cut for vector plots. . . . . . . .(cutsnaps) =   1.00
#      Subsampling of velocity model display. (subsamp_postscript) =      1
#
#
#  I t e r a t i o n s
#  ===================
#
#      Number of time iterations . . . . .(NSTEP) =    1600
#      Time step increment. . . . . . . . . .(DT) =   1.100000E-03
#      Total simulation duration . . . . . (ttot) =   1.760000E+00
#
#
#  reading mesh databases:
#  reading nodal coordinates...
#
#  -- Spectral Elements --
#
#
#      Number of spectral elements . . . . . . . . .  (nspec) =   5041
#      Number of control nodes per element . . . . . (NGNOD) =      9
#      Number of points in X-direction . . . . . . . (NGLLX) =      5
#      Number of points in Y-direction . . . . . . . (NGLLZ) =      5
#      Number of points per element. . . . . . (NGLLX*NGLLZ) =     25
#      Number of points for display . . . . . . (pointsdisp) =      6
#      Number of element material sets . . . . . . . (numat) =      4
#      Number of acoustic forcing elements (nelem_acforcing) =      0
#      Number of acoustic free surf (nelem_acoustic_surface) =      0
#
#  reading attenuation setup...
#  reading material properties..
#
#
#  M a t e r i a l   s e t s :   2 D  (p o r o) e l a s t i c i t y
#  ======================================================
#
#      Number of material sets . . . . . . (numat) =     4
#
#
#      ----------------------------------------
#      -- Elastic (solid) isotropic material --
#      ----------------------------------------
#      Material set number. . . . . . . . (jmat) =     1
#      P-wave velocity. . . . . . . . . . . (cp) = 3.00000000E+03
#      S-wave velocity. . . . . . . . . . . (cs) = 1.80000000E+03
#      Mass density. . . . . . . . . . (density) = 2.70000000E+03
#      Poisson's ratio. . . . . . . . .(poisson) = 2.18750000E-01
#      First Lame parameter Lambda. . . (lambda) = 6.80400000E+09
#      Second Lame parameter Mu. . . . . . .(mu) = 8.74800000E+09
#      Bulk modulus Kappa . . . . . . . .(kappa) = 1.55520000E+10
#      Young's modulus E. . . . . . . . .(young) = 2.21002105E+10
#      QKappa_attenuation .  . . . . . .(QKappa) = 9.99900000E+03
#      Qmu_attenuation . . . . . . . . . . (Qmu) = 9.99900000E+03
#
#
#
#      -------------------------------
#      -- Acoustic (fluid) material --
#      -------------------------------
#      Material set number. . . . . . . . (jmat) =     2
#      P-wave velocity. . . . . . . . . . . (cp) = 2.70000000E+03
#      Mass density. . . . . . . . . . (density) = 2.50000000E+03
#      Bulk modulus Kappa . . . . . . . .(kappa) = 1.82250000E+10
#      QKappa_attenuation. . . . . . . .(QKappa) = 9.99900000E+03
#      Qmu_attenuation. . . . . . . . . . .(Qmu) = 9.99900000E+03
#
#
#
#      ----------------------------------------
#      -- Elastic (solid) isotropic material --
#      ----------------------------------------
#      Material set number. . . . . . . . (jmat) =     3
#      P-wave velocity. . . . . . . . . . . (cp) = 2.50000000E+03
#      S-wave velocity. . . . . . . . . . . (cs) = 1.44337500E+03
#      Mass density. . . . . . . . . . (density) = 2.20000000E+03
#      Poisson's ratio. . . . . . . . .(poisson) = 2.50000350E-01
#      First Lame parameter Lambda. . . (lambda) = 4.58334188E+09
#      Second Lame parameter Mu. . . . . . .(mu) = 4.58332906E+09
#      Bulk modulus Kappa . . . . . . . .(kappa) = 9.16667094E+09
#      Young's modulus E. . . . . . . . .(young) = 1.17857057E+10
#      QKappa_attenuation .  . . . . . .(QKappa) = 9.99900000E+03
#      Qmu_attenuation . . . . . . . . . . (Qmu) = 9.99900000E+03
#
#
#
#      ----------------------------------------
#      -- Elastic (solid) isotropic material --
#      ----------------------------------------
#      Material set number. . . . . . . . (jmat) =     4
#      P-wave velocity. . . . . . . . . . . (cp) = 2.20000000E+03
#      S-wave velocity. . . . . . . . . . . (cs) = 1.34337500E+03
#      Mass density. . . . . . . . . . (density) = 2.20000000E+03
#      Poisson's ratio. . . . . . . . .(poisson) = 2.02726178E-01
#      First Lame parameter Lambda. . . (lambda) = 2.70751188E+09
#      Second Lame parameter Mu. . . . . . .(mu) = 3.97024406E+09
#      Bulk modulus Kappa . . . . . . . .(kappa) = 6.67775594E+09
#      Young's modulus E. . . . . . . . .(young) = 9.94066572E+09
#      QKappa_attenuation .  . . . . . .(QKappa) = 9.99900000E+03
#      Qmu_attenuation . . . . . . . . . . (Qmu) = 9.99900000E+03
#
#  reading interfaces informations...
#    number of interfaces         =            0
#
#  reading absorbing boundary...
#    Total number of absorbing elements =          284
#
#    any absorbing boundary flag        =  T
#    PML boundary flag                  =  F
#    Stacey boundary flag               =  T
#
#
#  Absorbing boundaries:
#    using Stacey absorbing boundary conditions
#
#    Total number of absorbing elements:          284
#      nspec_left   =           71
#      nspec_right  =           71
#      nspec_bottom =           71
#      nspec_top    =           71
#
#
#  reading acoustic forcing...
#    acoustic forcing                             =  F
#    number of acoustic forcing boundary elements =            0
#
#  reading free surface information...
#    number of acoustic free surface boundary elements =            0
#  reading coupling surfaces...
#    number of fluid-solid edges  =            0
#    number of fluid-poro  edges  =            0
#    number of solid-poro  edges  =            0
#
#  reading tangential curves...
#    number of tangential curve nodes =            0
#
#  reading axial elements...
#    number of axial elements     =            0
#
#  done reading mesh databases
#
#
#  Setting up mesh
#
#  Generating global mesh numbering (fast version)...
#
#  Mesh numbering:
#    Total number of elements:         5041
#
#    Total number of acoustic elements           =            0
#    Total number of elastic/visco/poro elements =         5041
#
#  Exact total number of grid points in the mesh:        81225
#  Mesh dimensions:
#    Xmin,Xmax of the whole mesh =    0.0000000000000000        4000.0000000000005
#    Zmin,Zmax of the whole mesh =    0.0000000000000000        4000.0000000000009
#
#  Material properties:
#    MODEL                 : default
#    nspec                 :         5041
#    assign external model :  F
#
#    setting up material arrays
#    all material arrays done
#
#  Domains:
#    total number of acoustic elements        =            0
#    total number of elastic elements         =         5041
#    total number of poroelastic elements     =            0
#
#  Setting up MPI communication arrays
#
#    maximum number of MPI interfaces (for a single slice) =            0
#
#    This is a single process simulation, no need for MPI communication
#
#    number of outer elements  =            0
#    number of inner elements  =         5041
#
#    percentage of outer elements    0.00000000     %
#    percentage of inner elements    100.000000     %
#
#    number of global nodes in outer elements  =            0
#    number of global nodes in inner elements  =        81225
#
#    determining communication phases:
#    elastic domains:
#    total number of outer/inner elements =            0        5041
#    total percentage of outer elements    0.00000000     %
#    total percentage of inner elements    100.000000     %
#
#  All mesh setup done successfully
#
#  sources:
#    Total number of sources:            1
#
#
#    Setting parameters for source           1
#
#      Source Type. . . . . . . . . . . . . . = Collocated Force
#      X-position (meters). . . . . . . . . . =    1.0000000000E+03
#      Y-position (meters). . . . . . . . . . =    2.0000000000E+03
#      Fundamental frequency (Hz) . . . . . . =    1.0000000000E+01
#      Time delay (s) . . . . . . . . . . . . =    0.0000000000E+00
#      Multiplying factor . . . . . . . . . . =    1.0000000000E+10
#      Angle from vertical direction (deg). . =    0.0000000000E+00
#
#
#    Source:            1
#      Onset time. . . . . . =  -0.12000000000000000
#      Fundamental period. . =   0.10000000000000001
#      Fundamental frequency =    10.000000000000000
#      The onset time is ok
#
#  Source:            1
#  *******************************
#   locating force source
#  *******************************
#
#  Force source:
#              original x:    1000.00000
#              original z:    2000.00000
#  Closest estimate found:    0.00000000      m away
#   in rank            0
#   in element         2503
#   in elastic domain
#   at xi,gamma coordinates =   0.50000000000000111       -1.6734554797903273E-015
#
#
#  end of force source detection
#
#
#  receivers:
#
#  Total number of receivers =            4
#
#
#  ********************
#   locating receivers
#  ********************
#
#  reading receiver information from the ./DATA/STATIONS file
#
#
#  Station #            1     AA      S0001
#              original x:    3000.00000
#              original z:    2000.00000
#  Closest estimate found:    0.00000000      m away
#   in rank            0
#   in element         2539
#   in elastic domain
#   at xi,gamma coordinates =  -0.49999999999999462        1.9505127504582380E-017
#  Distance from source:    2000.00000      m
#
#
#  Station #            2     AA      S0002
#              original x:    3000.00000
#              original z:    2000.00000
#  Closest estimate found:    0.00000000      m away
#   in rank            0
#   in element         2539
#   in elastic domain
#   at xi,gamma coordinates =  -0.49999999999999462        1.9505127504582380E-017
#  Distance from source:    2000.00000      m
#
#
#  Station #            3     AA      S0003
#              original x:    3000.00000
#              original z:    2000.00000
#  Closest estimate found:    0.00000000      m away
#   in rank            0
#   in element         2539
#   in elastic domain
#   at xi,gamma coordinates =  -0.49999999999999462        1.9505127504582380E-017
#  Distance from source:    2000.00000      m
#
#
#  Station #            4     AA      S0001
#              original x:    3000.00000
#              original z:    2000.00000
#  Closest estimate found:    0.00000000      m away
#   in rank            0
#   in element         2539
#   in elastic domain
#   at xi,gamma coordinates =  -0.49999999999999462        1.9505127504582380E-017
#  Distance from source:    2000.00000      m
#
#  maximum error in location of all the receivers:    0.00000000      m
#
#  end of receiver detection
#
#  found a total of            4  receivers, this is okay
#
#
#  Preparing timerun:
#
#
#  Preparing timerun constants
#
#  Preparing array allocations
#    arrays for elastic domains
#    done initialization
#
#  Preparing Stacey boundaries
#    total number of absorbing boundary faces/edges:          284
#
#  Attenuation:
#    viscoelastic  attenuation: F (shear & bulk attenuation in elastic domains)
#    viscoacoustic attenuation: F (bulk attenuation in acoustic domains)
#
#  Preparing mass matrices
#    initializing mass matrices
#    adding Stacey contributions to mass matrix
#    inverting mass matrices
#
#
#  Preparing source time function
#    time stepping scheme:   Newmark
#    time stepping stages:            1
#    time step size      :    1.09999999E-03
#
#    number of time steps:         1600
#    number of sources   :            1
#
#    saving the source time function in a text file...
#
#  Movie simulation:
#    color images         - JPEG image type:            2
#    number of steps between outputs       :          100
#
#  Preparing image coloring: jpeg
#    allocating color image arrays
#    locating all the pixels of color images
#    total number of image pixels =       577599
#    done locating all the pixels of color images
#    coloring image background based on vp
#
#  Checking mesh and stability
#
#  ********
#  Model: P (or PI) velocity min,max =    3000.0000000000000        3000.0000000000000
#  Model: S velocity min,max         =    1800.0000263374484        1800.0000263374484
#  Model: density min,max            =    2700.0000000000000        2700.0000000000000
#  ********
#
#
#  *********************************************
#  *** Verification of simulation parameters ***
#  *********************************************
#
#  *** Max grid size =    56.338028169014706
#  *** Min grid size =    56.338028169013796
#  *** Max/min ratio =    1.0000000000000162
#
#  *** Minimum GLL point distance  =    9.7280656138597479
#  *** Average GLL point distance  =    14.084507042253449
#
#  *** Minimum period resolved     =    3.9123630100473220E-002
#  *** Maximum frequency resolved  =    25.560000373991485      Hz
#
#  *** Maximum suggested time step                 =    1.6213442689766247E-003
#  *** Maximum suggested (Ricker) source frequency =    10.224000149596595
#
#  *** for DT :    1.09999999E-03
#  *** Max CFL stability condition of the time scheme based on P wave velocity (must be below about 0.50 or so) =   0.33922468382789667
#
#  ----
#  Number of points per wavelength:
#  ----
#    Source            1
#    maximum dominant source frequency =    25.000000000000000      Hz
#
#    Nb pts / lambdaP_fmax min =    8.52000046
#    Nb pts / lambdaP_fmax max =    8.52000046
#
#    Nb pts / lambdaS_fmax min =    5.11199999
#    Nb pts / lambdaS_fmax max =    5.11199999
#
#  -----------------------------------------
#
#  histogram of min number of points per S wavelength in solid regions:
#
#  there are         5041  elements out of         5041  in solid regions
#    (i.e.,    100.000000     % of the total)
#
#  (too small = poor resolution of calculations -
#   too big = wasting memory and CPU time)
#  (threshold value is around 4.5 points per S wavelength
#   in elastic regions and 5.5 per P wavelength in fluid regions):
#
#    5.06088018      -    5.06599188               0     0.00000000      %
#    5.06599188      -    5.07110405               0     0.00000000      %
#    5.07110405      -    5.07621622               0     0.00000000      %
#    5.07621622      -    5.08132792               0     0.00000000      %
#    5.08132792      -    5.08644009               0     0.00000000      %
#    5.08644009      -    5.09155226               0     0.00000000      %
#    5.09155226      -    5.09666395               0     0.00000000      %
#    5.09666395      -    5.10177612               0     0.00000000      %
#    5.10177612      -    5.10688829               0     0.00000000      %
#    5.10688829      -    5.11199999            3175     62.9835358      %
#    5.11199999      -    5.11711216            1866     37.0164642      %
#    5.11711216      -    5.12222385               0     0.00000000      %
#    5.12222385      -    5.12733603               0     0.00000000      %
#    5.12733603      -    5.13244820               0     0.00000000      %
#    5.13244820      -    5.13755989               0     0.00000000      %
#    5.13755989      -    5.14267206               0     0.00000000      %
#    5.14267206      -    5.14778423               0     0.00000000      %
#    5.14778423      -    5.15289593               0     0.00000000      %
#    5.15289593      -    5.15800810               0     0.00000000      %
#    5.15800810      -    5.16312027               0     0.00000000      %
#
#  total percentage =    100.00000000000000       %
#
#
#  total number of elements in fluid and solid regions =         5041
#
#
#  done, preparation successful
#
#
#  =========================================
#  =  T i m e  e v o l u t i o n  l o o p  =
#  =========================================
#
#
#  Starting time iteration loop ...
#
#
#  ******************************************************************
# Time step number       5   t =    0.0044 s out of    1600
#  ******************************************************************
#  We have done   0.250156343     % of the total
#  Max norm of vector field in solid (elastic) =    1.58623948E-06
#  Elapsed time in seconds =    7.9998970031738281E-003
#  Elapsed time in hh:mm:ss =      0 h 00 m 00 s
#  Mean elapsed time per time step in seconds =    1.5999794006347657E-003
#  Time steps remaining =         1595
#  Estimated remaining time in seconds =    2.5519671440124512
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 02 s
#  Estimated total run time in seconds =    2.5599670410156250
#  Estimated total run time in hh:mm:ss =      0 h 00 m 02 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step            5
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    2.7587882414081832E-006
#  Color image created
#
#
#  ******************************************************************
# Time step number     100   t =    0.1089 s out of    1600
#  ******************************************************************
#  We have done    6.19136953     % of the total
#  Max norm of vector field in solid (elastic) =   0.121943340
#  Elapsed time in seconds =   0.19000005722045898
#  Elapsed time in hh:mm:ss =      0 h 00 m 00 s
#  Mean elapsed time per time step in seconds =    1.9000005722045899E-003
#  Time steps remaining =         1500
#  Estimated remaining time in seconds =    2.8500008583068848
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 02 s
#  Estimated total run time in seconds =    3.0400009155273438
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          100
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =   0.12080080807209015
#  Color image created
#
#
#  ******************************************************************
# Time step number     200   t =    0.2189 s out of    1600
#  ******************************************************************
#  We have done    12.4452782     % of the total
#  Max norm of vector field in solid (elastic) =    9.45594162E-02
#  Elapsed time in seconds =   0.37999987602233887
#  Elapsed time in hh:mm:ss =      0 h 00 m 00 s
#  Mean elapsed time per time step in seconds =    1.8999993801116944E-003
#  Time steps remaining =         1400
#  Estimated remaining time in seconds =    2.6599991321563721
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 02 s
#  Estimated total run time in seconds =    3.0399990081787109
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          200
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    9.3998230993747711E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     300   t =    0.3289 s out of    1600
#  ******************************************************************
#  We have done    18.6991863     % of the total
#  Max norm of vector field in solid (elastic) =    6.28829822E-02
#  Elapsed time in seconds =   0.57099986076354980
#  Elapsed time in hh:mm:ss =      0 h 00 m 00 s
#  Mean elapsed time per time step in seconds =    1.9033328692118327E-003
#  Time steps remaining =         1300
#  Estimated remaining time in seconds =    2.4743327299753823
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 02 s
#  Estimated total run time in seconds =    3.0453325907389321
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          300
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    6.2703341245651245E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     400   t =    0.4389 s out of    1600
#  ******************************************************************
#  We have done    24.9530964     % of the total
#  Max norm of vector field in solid (elastic) =    5.03191240E-02
#  Elapsed time in seconds =   0.76399993896484375
#  Elapsed time in hh:mm:ss =      0 h 00 m 00 s
#  Mean elapsed time per time step in seconds =    1.9099998474121093E-003
#  Time steps remaining =         1200
#  Estimated remaining time in seconds =    2.2919998168945312
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 02 s
#  Estimated total run time in seconds =    3.0559997558593750
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          400
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    5.0206054002046585E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     500   t =    0.5489 s out of    1600
#  ******************************************************************
#  We have done    31.2070045     % of the total
#  Max norm of vector field in solid (elastic) =    4.31740582E-02
#  Elapsed time in seconds =   0.95700001716613770
#  Elapsed time in hh:mm:ss =      0 h 00 m 00 s
#  Mean elapsed time per time step in seconds =    1.9140000343322754E-003
#  Time steps remaining =         1100
#  Estimated remaining time in seconds =    2.1054000377655031
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 02 s
#  Estimated total run time in seconds =    3.0624000549316408
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          500
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    4.3113190680742264E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     600   t =    0.6589 s out of    1600
#  ******************************************************************
#  We have done    37.4609146     % of the total
#  Max norm of vector field in solid (elastic) =    3.83773074E-02
#  Elapsed time in seconds =    1.1549999713897705
#  Elapsed time in hh:mm:ss =      0 h 00 m 01 s
#  Mean elapsed time per time step in seconds =    1.9249999523162841E-003
#  Time steps remaining =         1000
#  Estimated remaining time in seconds =    1.9249999523162842
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 01 s
#  Estimated total run time in seconds =    3.0799999237060547
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          600
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.8336355239152908E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     700   t =    0.7689 s out of    1600
#  ******************************************************************
#  We have done    43.7148209     % of the total
#  Max norm of vector field in solid (elastic) =    3.62326577E-02
#  Elapsed time in seconds =    1.3510000705718994
#  Elapsed time in hh:mm:ss =      0 h 00 m 01 s
#  Mean elapsed time per time step in seconds =    1.9300001008169991E-003
#  Time steps remaining =          900
#  Estimated remaining time in seconds =    1.7370000907352992
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 01 s
#  Estimated total run time in seconds =    3.0880001613071988
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          700
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.6046616733074188E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     800   t =    0.8789 s out of    1600
#  ******************************************************************
#  We have done    49.9687309     % of the total
#  Max norm of vector field in solid (elastic) =    3.47612537E-02
#  Elapsed time in seconds =    1.5429999828338623
#  Elapsed time in hh:mm:ss =      0 h 00 m 01 s
#  Mean elapsed time per time step in seconds =    1.9287499785423279E-003
#  Time steps remaining =          800
#  Estimated remaining time in seconds =    1.5429999828338623
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 01 s
#  Estimated total run time in seconds =    3.0859999656677246
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          800
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.4544799476861954E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number     900   t =    0.9889 s out of    1600
#  ******************************************************************
#  We have done    56.2226410     % of the total
#  Max norm of vector field in solid (elastic) =    3.35423984E-02
#  Elapsed time in seconds =    1.7400000095367432
#  Elapsed time in hh:mm:ss =      0 h 00 m 01 s
#  Mean elapsed time per time step in seconds =    1.9333333439297145E-003
#  Time steps remaining =          700
#  Estimated remaining time in seconds =    1.3533333407508001
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 01 s
#  Estimated total run time in seconds =    3.0933333502875433
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step          900
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.3263139426708221E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1000   t =    1.0989 s out of    1600
#  ******************************************************************
#  We have done    62.4765472     % of the total
#  Max norm of vector field in solid (elastic) =    3.21214683E-02
#  Elapsed time in seconds =    1.9370000362396240
#  Elapsed time in hh:mm:ss =      0 h 00 m 01 s
#  Mean elapsed time per time step in seconds =    1.9370000362396241E-003
#  Time steps remaining =          600
#  Estimated remaining time in seconds =    1.1622000217437745
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 01 s
#  Estimated total run time in seconds =    3.0992000579833983
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step         1000
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.1831994652748108E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1100   t =    1.2089 s out of    1600
#  ******************************************************************
#  We have done    68.7304535     % of the total
#  Max norm of vector field in solid (elastic) =    3.12877558E-02
#  Elapsed time in seconds =    2.1299998760223389
#  Elapsed time in hh:mm:ss =      0 h 00 m 02 s
#  Mean elapsed time per time step in seconds =    1.9363635236566716E-003
#  Time steps remaining =          500
#  Estimated remaining time in seconds =   0.96818176182833582
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 00 s
#  Estimated total run time in seconds =    3.0981816378506748
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step         1100
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.1150098890066147E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1200   t =    1.3189 s out of    1600
#  ******************************************************************
#  We have done    74.9843674     % of the total
#  Max norm of vector field in solid (elastic) =    3.08713894E-02
#  Elapsed time in seconds =    2.3269999027252197
#  Elapsed time in hh:mm:ss =      0 h 00 m 02 s
#  Mean elapsed time per time step in seconds =    1.9391665856043497E-003
#  Time steps remaining =          400
#  Estimated remaining time in seconds =   0.77566663424173987
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 00 s
#  Estimated total run time in seconds =    3.1026665369669595
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step         1200
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    3.0941855162382126E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1300   t =    1.4289 s out of    1600
#  ******************************************************************
#  We have done    81.2382736     % of the total
#  Max norm of vector field in solid (elastic) =    2.54909713E-02
#  Elapsed time in seconds =    2.5260000228881836
#  Elapsed time in hh:mm:ss =      0 h 00 m 02 s
#  Mean elapsed time per time step in seconds =    1.9430769406832181E-003
#  Time steps remaining =          300
#  Estimated remaining time in seconds =   0.58292308220496547
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 00 s
#  Estimated total run time in seconds =    3.1089231050931492
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step         1300
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    2.5397764518857002E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1400   t =    1.5389 s out of    1600
#  ******************************************************************
#  We have done    87.4921799     % of the total
#  Max norm of vector field in solid (elastic) =    2.48813946E-02
#  Elapsed time in seconds =    2.7249999046325684
#  Elapsed time in hh:mm:ss =      0 h 00 m 02 s
#  Mean elapsed time per time step in seconds =    1.9464285033089774E-003
#  Time steps remaining =          200
#  Estimated remaining time in seconds =   0.38928570066179546
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 00 s
#  Estimated total run time in seconds =    3.1142856052943637
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step         1400
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    2.5000827386975288E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1500   t =    1.6489 s out of    1600
#  ******************************************************************
#  We have done    93.7460938     % of the total
#  Max norm of vector field in solid (elastic) =    2.45201606E-02
#  Elapsed time in seconds =    2.9219999313354492
#  Elapsed time in hh:mm:ss =      0 h 00 m 02 s
#  Mean elapsed time per time step in seconds =    1.9479999542236328E-003
#  Time steps remaining =          100
#  Estimated remaining time in seconds =   0.19479999542236329
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 00 s
#  Estimated total run time in seconds =    3.1167999267578126
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#  The run will finish approximately on: Tue Feb 07, 2023 17:54
#
#  Creating color image of size          760  x          800  for time step         1500
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    2.4421364068984985E-002
#  Color image created
#
#
#  ******************************************************************
# Time step number    1600   t =    1.7589 s out of    1600
#  ******************************************************************
#  We have done    100.000000     % of the total
#  Max norm of vector field in solid (elastic) =    2.38593593E-02
#  Elapsed time in seconds =    3.1159999370574951
#  Elapsed time in hh:mm:ss =      0 h 00 m 03 s
#  Mean elapsed time per time step in seconds =    1.9474999606609344E-003
#  Time steps remaining =            0
#  Estimated remaining time in seconds =    0.0000000000000000
#  Estimated remaining time in hh:mm:ss =      0 h 00 m 00 s
#  Estimated total run time in seconds =    3.1159999370574951
#  Estimated total run time in hh:mm:ss =      0 h 00 m 03 s
#
#
#  Total number of time steps done:         1600
#  Writing the seismograms by main proc alone took    7.55119324E-03  seconds
#
#  Creating color image of size          760  x          800  for time step         1600
#  drawing scalar image of the forward wavefield displacement...
#  Color image maximum amplitude =    2.3873390629887581E-002
#  Color image created
#
#
#  Total duration of the time loop in seconds =    3.13111901      s
#  Total number of time steps =         1600
#  Average duration of a time step of the time loop =    1.95694948E-03  s
#  Total number of spectral elements in the mesh =         5041
#      of which         5041  are regular elements
#      and            0  are PML elements.
#  Average duration of the calculation per spectral element =    3.88206587E-07  s
#
#
#  Total duration of the timeloop in seconds, measured using
#  date and time of the system :    3.13700008      s
#
#
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#  Program SPECFEM2D:
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#  Test of SPECFEM2D with curved interfaces
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------
#  D a t e : 07 - 02 - 2023                                 T i m e  : 17:54:03
#  -------------------------------------------------------------------------------
#  -------------------------------------------------------------------------------

# %% [markdown]
# ### 3. Plot synthetic seismogram

# %%
# Read synthetic seismogram
synt = read_trace("./OUTPUT_FILES/AA.S0001.BXY.semd")

# Process data
synt.detrend("simple")
synt.taper(0.05)
synt.filter("bandpass", freqmin=0.01, freqmax=20)

fig, ax = plt.subplots(figsize=(20, 4))
# Use the beginning time value from the file: tr.times()+tr.stats.b
ax.plot(synt.times()+synt.stats.b, synt.data, "r", label="synt")
ax.set_xlim(synt.stats.b, synt.times()[-1]+synt.stats.b)
ax.legend()
ax.set_xlabel("Time (s)");
ax.set_ylabel("Displacement (m)");

# %%
### 4. Snapshots 
images=[]
# collect all .jpg files in OUTPUT_FILES directory
fs = !ls OUTPUT_FILES/*.jpg
# Print .jpg files
for ea in fs:
    images.append(dp.Image(filename=ea,format='jpg'))
for ea in fs:
    dp.display(Image.open(ea))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF17F0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1490>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF15B0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1550>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1520>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1550>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF14C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1550>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1700>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CAD05190>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1A30>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CACF1700>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CAD05130>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CAD050A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CAD051C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CAD05190>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x800 at 0x7FA2CAD05130>
